# %% [markdown]
# ## Diet vs. Excercise only
#
# A test is conducted to explore the fat loss differences between diet only and excercise only regimes. The quesion is, "<b>did excercisers lose more fat than dieters?</b>". The dieters subjects weight in kilos is in the diet_only list and the same for the exercicers in excercise_only list.
#
# Tasks
#
# 1) Set up a clear null and alternatie hypothesis, determininig if this is a one-sided or two-sided test
#
# 2) Make a decision by calculating the p-value. If a conclusion cannot be made, clearly state why.

# %%
import random
import numpy as np
diet_only = []
excercise_only = []
for i in range(50):
    diet_only.append(random.randint(50,95))
for i in range(41):
    excercise_only.append(random.randint(44,84))
